# %%
# !python3.10 -m venv synthcity_env
# !synthcity_env/bin/pip install synthcity ipkernal
# !synthcity_env/bin/python -m ipykernel install --user --name=synthcity_env
# Out:
# /usr/bin/sh: 1: python3.10: not found
# /usr/bin/sh: 1: synthcity_env/bin/pip: not found
# /usr/bin/sh: 1: synthcity_env/bin/python: not found

# %%
import os

# %%
os.getcwd()
# Out:
# '/usr/bin'

# %%
# !ls
# Out:
# '['				      paperconf
#  411toppm			      partx
#  aclocal			      passwd
#  aclocal-1.16			      paste
#  addpart			      patch
#  addr2line			      pathchk
#  animate			      pbmclean
#  animate-im6			      pbmlife
#  animate-im6.q16		      pbmmake
#  anytopnm			      pbmmask
#  apt				      pbmminkowski
#  apt-cache			      pbmnoise
#  apt-cdrom			      pbmpage
#  apt-config			      pbmpscale
#  apt-get			      pbmreduce
#  apt-key			      pbmtext
#  apt-mark			      pbmtextps
#  ar				      pbmto10x
#  arch				      pbmto4425
#  as				      pbmtoascii
#  asciitopgm			      pbmtoatk
#  atktopbm			      pbmtobbnbg
#  autoconf			      pbmtocis
#  autoheader			      pbmtocmuwm
#  autom4te			      pbmtodjvurle
#  automake			      pbmtoepsi
#  automake-1.16			      pbmtoepson
#  autoreconf			      pbmtoescp2
#  autoscan			      pbmtog3
#  autoupdate			      pbmtogem
#  avstopam			      pbmtogo
#  awk				      pbmtoibm23xx
#  b2sum				      pbmtoicon
#  background			      pbmtolj
# ...

# %%
import os

for root, dirs, files in os.walk("/"):
    for f in files:
        if f.endswith(".ipynb"):
            print(os.path.join(root, f))
# Out:
# /usr/bin/synthData_survival.ipynb
# /usr/bin/Untitled.ipynb
# /usr/bin/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# /usr/bin/.ipynb_checkpoints/synthData_survival-checkpoint.ipynb
